# %% [markdown]
# <h1 style="font-size:3rem; color:orange;">Привіт Наш Юпітер <span style="font-size:3rem; color:blue; ">;)</span></h1>

# %% [markdown]
# # Підключення фото

# %% [markdown]
# <img src="https://arkvalleyvoice.com/wp-content/uploads/2026/05/Screenshot-2026-05-29-at-11-14-34-Ai-technology-microchip-background-digital-transformation-concept-Free-Photo.png"/>

# %% [markdown]
# ## Simple code

# %%
print("Сюди влазить Python")
# Out:
# Сюди влазить Python

# %%
person = input("Ваше ім'я?")
message = "Привіт, {}!".format(person)
print(message)
# Out:
# Ваше ім'я? Telepuzik
# Привіт, Telepuzik!

# %%
story = """Ще не вмерла Україна
Ні слава ні воля"""
print(story)
print(len(story))
# Out:
# Ще не вмерла Україна
# Ні слава ні воля
# 37

# %%
x = 12 
y = 8
z = (x*3)/y
m = (x*3)%y
print(z)
print(m)
# Out:
# 4.5
# 4

# %%
friends = ['Іван', 'Семен', 'Віктор', 'Мирослава']
print(friends[1])
# Out:
# Семен
